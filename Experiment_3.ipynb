# %% [markdown]
# <a href="https://colab.research.google.com/github/faisalkhan786hi/Machine-Learning/blob/main/Experiment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXPERIMENT - 3**
#
# ---

# %% [markdown]
# # Statistical Summary and basic plotting

# %% [markdown]
# ![Screenshot 2023-04-04 010450.png](data:image/png;base64,...)

# %% [markdown]
# a) Generate various summary statistics such as mean, standard deviation, minimum value,
# maximum value, and “1,2 & 3rd quantiles” for all the numerical attributes.

# %%
import pandas as pd
df = pd.read_csv('/content/mtcar.csv')
summary = df.describe()
print(summary)
# Out:
#              mpg       cyl        disp          hp      drat        wt  \
# count   9.000000  9.000000    9.000000    9.000000  9.000000  9.000000
# mean   20.500000  5.777778  213.166667  122.777778  3.486667  3.093333
# std     3.052458  1.563472   94.629726   54.570546  0.455192  0.415173
# min    14.300000  4.000000  108.000000   62.000000  2.760000  2.320000
# 25%    18.700000  4.000000  146.700000   95.000000  3.150000  2.875000
# 50%    21.000000  6.000000  160.000000  110.000000  3.690000  3.190000
# 75%    22.800000  6.000000  258.000000  110.000000  3.900000  3.440000
# max    24.400000  8.000000  360.000000  245.000000  3.920000  3.570000
#
#             qsec        vs        am  gear      carb
# count   9.000000  9.000000  9.000000   4.0  9.000000
# mean   18.612222  0.555556  0.333333   3.0  2.333333
# std     2.262984  0.527046  0.500000   0.0  1.322876
# min    15.840000  0.000000  0.000000   3.0  1.000000
# 25%    17.020000  0.000000  0.000000   3.0  1.000000
# 50%    18.610000  1.000000  0.000000   3.0  2.000000
# 75%    20.000000  1.000000  1.000000   3.0  4.000000
# max    22.900000  1.000000  1.000000   3.0  4.000000

# %% [markdown]
# b) Count the number of non-NaN items per feature

# %%
non_nan_counts = df.count()
print(non_nan_counts)
# Out:
# model    9
# mpg      9
# cyl      9
# disp     9
# hp       9
# drat     9
# wt       9
# qsec     9
# vs       9
# am       9
# gear     4
# carb     9
# dtype: int64

# %% [markdown]
# c) Calculate mean absolute deviation.

# %%
mad = (df - df.mean()).abs().mean()
print(mad)
# Out:
# am        0.444444
# carb      1.111111
# cyl       1.185185
# disp     77.851852
# drat      0.405926
# gear      0.000000
# hp       38.765432
# model          NaN
# mpg       2.311111
# qsec      1.802469
# vs        0.493827
# wt        0.325556
# dtype: float64
# <ipython-input-7-76d5b63c98ee>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mad = (df - df.mean()).abs().mean()

# %% [markdown]
# d) Calculate median for any of the numeric type column

# %%
mpg_median = df['mpg'].median()

print(mpg_median)
# Out:
# 21.0

# %% [markdown]
# e) Calculate mean any of the numeric type column

# %%
mpg_mean = df['mpg'].mean()

print(mpg_mean)
# Out:
# 20.5

# %% [markdown]
# f) Calculate mode for “hp” column

# %%
hp_mode = df['hp'].mode()[0]

print(hp_mode)
# Out:
# 110

# %% [markdown]
# g) Calculate skewness for “disp”

# %%
disp_skew = df['disp'].skew()

print(disp_skew)
# Out:
# 0.8130458592957428

# %% [markdown]
# h) Find the coefficient of correlation between all the numeric attributes.

# %%
corr_matrix = df.corr()

print(corr_matrix)
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.864339 -0.815046 -0.902600  0.599695 -0.588555  0.548974
# cyl  -0.864339  1.000000  0.908522  0.857886 -0.566734  0.555888 -0.709261
# disp -0.815046  0.908522  1.000000  0.856198 -0.718261  0.758071 -0.459926
# hp   -0.902600  0.857886  0.856198  1.000000 -0.392695  0.511486 -0.624205
# drat  0.599695 -0.566734 -0.718261 -0.392695  1.000000 -0.725526  0.039264
# wt   -0.588555  0.555888  0.758071  0.511486 -0.725526  1.000000  0.074776
# qsec  0.548974 -0.709261 -0.459926 -0.624205  0.039264  0.074776  1.000000
# vs    0.543888 -0.741620 -0.469514 -0.647091 -0.111154 -0.075216  0.849848
# am    0.270274 -0.213201 -0.558757 -0.253495  0.653570 -0.882162 -0.413908
# gear       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# carb -0.346704  0.402911  0.129310  0.439234  0.404791 -0.033001 -0.645812
#
#             vs        am  gear      carb
# mpg   0.543888  0.270274   NaN -0.346704
# cyl  -0.741620 -0.213201   NaN  0.402911
# disp -0.469514 -0.558757   NaN  0.129310
# hp   -0.647091 -0.253495   NaN  0.439234
# drat -0.111154  0.653570   NaN  0.404791
# wt   -0.075216 -0.882162   NaN -0.033001
# qsec  0.849848 -0.413908   NaN -0.645812
# vs    1.000000 -0.316228   NaN -0.836660
# am   -0.316228  1.000000   NaN  0.377964
# gear       NaN       NaN   NaN       NaN
# carb -0.836660  0.377964   NaN  1.000000

# %% [markdown]
# i) Scatter plot a graph between “hp” vs “mpg”

# %%
import matplotlib.pyplot as plt
plt.scatter(df['hp'], df['mpg'])
plt.xlabel('hp')
plt.ylabel('mpg')
plt.show()

# %% [markdown]
# j) Plot a density diagram (kde- kernel desity estimation) for “displacement”

# %%
df['disp'].plot.kde()
plt.xlabel('disp')
plt.show()

# %% [markdown]
# k) Plot a bar diagram for “CarName” vs “mpg”

# %%
grouped = df.groupby("model")["mpg"].mean()
grouped.plot(kind="bar")
plt.title("Average MPG by Car Name")
plt.xlabel("Car Name")
plt.ylabel("Average MPG")
plt.show()

# %% [markdown]
# l) Box plot the “hp” attribute.

# %%
import seaborn as sns
sns.boxplot(x=df['hp'])
plt.show()
